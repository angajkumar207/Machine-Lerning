# %% [markdown]
# # EDA : **Exploratory Data Analysis**

# %% [markdown]
# ## CRISP-DM : **Cross Industry Standard Process For Data Mining**
#
# - Steps for processing machine building model
#     - Business Understading
#     - Data Understanding >> **EDA**
#     - Data preparation
#         - Missing Value Treatment
#         - Data encoding
#         - Outlier Detection
#     - Modelling
#         - ML Algorithms
#     - Evaluation
#     - Deployment

# %% [markdown]
# - Data Ingestion (.csv, .xlsx, etc)
# - EDA (Exploratory Data Analysis)
# - Data Preparation/ Feature Engineering
# - Model Building
# - Model Evaluation

# %% [markdown]
# _EDA_ :
# - Profile of Data
#     - Number of rows
#     - Datatypes
#     - Duplicates
# - Statistical Based Analysis
#     - Five point summary
#     - Outliers
#     - Correlation
#     - Covairance
# - Graph Based Analysis
#     - Scatter plot
#     - Heatmap
#     - Box Plot
#     - Pairplot

# %% [markdown]
# ## How to do EDA?

# %% [markdown]
# (f1, f2, f3, ......... f100)
#
# To gain insights from the data - EDA
# 1. Uni-variant Analysis - one feature - Distplot
# 2. Bi-variant Analysis - two feature - Scatter plot
# 3. Multi-variant Analysis - Multiple feature - Heat map

# %%
# Library

import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\angaj\Downloads\googleplaystore.csv")

# %%
# print columns name
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# print some line of code (like 4 line)
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df.sample(2)
# Out:
#                                                     App        Category  \
# 8933                                            Live DV     PHOTOGRAPHY
# 1488  乐屋网: Buying a house, selling a house, renting ...  HOUSE_AND_HOME
#
#       Rating Reviews Size  Installs  Type Price Content Rating        Genres  \
# 8933     2.0      16  17M    1,000+  Free     0       Everyone   Photography
# 1488     3.7    2248  15M  100,000+  Free     0       Everyone  House & Home
#
#         Last Updated Current Ver Android Ver
# 8933     May 9, 2018       1.0.6  4.4 and up
# 1488  August 3, 2018      v3.1.1  4.0 and up

# %%
# total numbers of row and  columns 
df.shape
# Out:
# (10841, 13)

# %%
df.describe() # statical information for numerical data >> five point summery
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.describe(include = "all")
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
#          Type  Price Content Rating Genres    Last Updated  \
# count   10840  10841          10840  10841           10841
# unique      3     93              6    120            1378
# top      Free      0       Everyone  Tools  August 3, 2018
# freq    10039  10040           8714    842             326
# mean      NaN    NaN            NaN    NaN             NaN
# std       NaN    NaN            NaN    NaN             NaN
# min       NaN    NaN            NaN    NaN             NaN
# 25%       NaN    NaN            NaN    NaN             NaN
# 50%       NaN    NaN            NaN    NaN             NaN
# 75%       NaN    NaN            NaN    NaN             NaN
# max       NaN    NaN            NaN    NaN             NaN
#
#                Current Ver Android Ver
# count                10833       10838
# unique                2832          33
# top     Varies with device  4.1 and up
# freq                  1459        2451
# mean                   NaN         NaN
# std                    NaN         NaN
# min                    NaN         NaN
# 25%                    NaN         NaN
# 50%                    NaN         NaN
# 75%                    NaN         NaN
# max                    NaN         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.duplicated().sum()
# Out:
# 483

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10358 rows x 13 columns]

# %%
# not any duplicate values becaose duplicated value is droped
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes # all columns data types together
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
# one colunms data type 
df['Content Rating'].dtype
df['Rating'].dtype
# Out:
# dtype('float64')

# %%
df.Reviews.unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
# IT IS POSSIBLE THAT IN rEVIES COLUMNS THERE WEIGHT BE A VALUE WHICH IS STRING AND HENCE
# CONVERTING THE WHOLE COLUMNS INTO OBJECTS

# %%
type("T")
# Out:
# str

# %%
"1".isnumeric() # 1 is numeric inside string
# Out:
# True

# %%
df[~df.Reviews.str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df.Reviews
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10358, dtype: object

# %%
df_copy = df.copy()
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10358 rows x 13 columns]

# %%
# Resettting the index after dropping the duplicate values orignal index is null there
df_copy.reset_index(drop = True, inplace = True)

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10353     4.5      38                 53M       5,000+  Free     0
# 10354     5.0       4                3.6M         100+  Free     0
# 10355     NaN       3                9.5M       1,000+  Free     0
# 10356     4.5     114  Varies with device       1,000+  Free     0
# 10357     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10353       Everyone                  Education     July 25, 2017
# 10354       Everyone                  Education      July 6, 2018
# 10355       Everyone                    Medical  January 20, 2017
# 10356     Mature 17+          Books & Reference  January 19, 2015
# 10357       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10353                1.48          4.1 and up
# 10354                 1.0          4.1 and up
# 10355                 1.0          2.2 and up
# 10356  Varies with device  Varies with device
# 10357  Varies with device  Varies with device
#
# [10358 rows x 13 columns]

# %%
df_copy[~df_copy.Reviews.str.isnumeric()]
# Out:
#                                           App Category  Rating Reviews  \
# 9990  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#         Size Installs Type     Price Content Rating             Genres  \
# 9990  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#      Last Updated Current Ver Android Ver
# 9990       1.0.19  4.0 and up         NaN

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10358 entries, 0 to 10357
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          8893 non-null   float64
#  3   Reviews         10358 non-null  object
#  4   Size            10358 non-null  object
#  5   Installs        10358 non-null  object
#  6   Type            10357 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10350 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.0+ MB

# %%
df["Size"].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M',
#        '6.2M', '18k', '53M', '1.4M', '3.0M', '5.8M', '3.8M', '9.6M',
#        '45M', '63M', '49M', '77M', '4.4M', '4.8M', '70M', '6.9M', '9.3M',
#        '10.0M', '8.1M', '36M', '84M', '97M', '2.0M', '1.9M', '1.8M',
#        '5.3M', '47M', '556k', '526k', '76M', '7.6M', '59M', '9.7M', '78M',
#        '72M', '43M', '7.7M', '6.3M', '334k', '34M', '93M', '65M', '79M',
#        '100M', '58M', '50M', '68M', '64M', '67M', '60M', '94M', '232k',
#        '99M', '624k', '95M', '8.5k', '41k', '292k', '11k', '80M', '1.7M',
#        '74M', '62M', '69M', '75M', '98M', '85M', '82M', '96M', '87M',
#        '71M', '86M', '91M', '81M', '92M', '83M', '88M', '704k', '862k',
#        '899k', '378k', '266k', '375k', '1.3M', '975k', '980k', '4.1M',
#        '89M', '696k', '544k', '525k', '920k', '779k', '853k', '720k',
#        '713k', '772k', '318k', '58k', '241k', '196k', '857k', '51k',
#        '953k', '865k', '251k', '930k', '540k', '313k', '746k', '203k',
#        '26k', '314k', '239k', '371k', '220k', '730k', '756k', '91k',
#        '293k', '17k', '74k', '14k', '317k', '78k', '924k', '902k', '818k',
#        '81k', '939k', '169k', '45k', '475k', '965k', '90M', '545k', '61k',
#        '283k', '655k', '714k', '93k', '872k', '121k', '322k', '1.0M',
#        '976k', '172k', '238k', '549k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '705k', '306k', '904k', '473k', '175k',
#        '350k', '383k', '454k', '421k', '70k', '812k', '442k', '842k',
#        '417k', '412k', '459k', '478k', '335k', '782k', '721k', '430k',
#        '429k', '192k', '200k', '460k', '728k', '496k', '816k', '414k',
#        '506k', '887k', '613k', '243k', '569k', '778k', '683k', '592k',
#        '319k', '186k', '840k', '647k', '191k', '373k', '437k', '598k',
#        '716k', '585k', '982k', '222k', '219k', '55k', '948k', '323k',
#        '691k', '511k', '951k', '963k', '25k', '554k', '351k', '27k',
#        '82k', '208k', '913k', '514k', '551k', '29k', '103k', '898k',
#        '743k', '116k', '153k', '209k', '353k', '499k', '173k', '597k',
#        '809k', '122k', '411k', '400k', '801k', '787k', '237k', '50k',
#        '643k', '986k', '97k', '516k', '837k', '780k', '961k', '269k',
#        '20k', '498k', '600k', '749k', '642k', '881k', '72k', '656k',
#        '601k', '221k', '228k', '108k', '940k', '176k', '33k', '663k',
#        '34k', '942k', '259k', '164k', '458k', '245k', '629k', '28k',
#        '288k', '775k', '785k', '636k', '916k', '994k', '309k', '485k',
#        '914k', '903k', '608k', '500k', '54k', '562k', '847k', '957k',
#        '688k', '811k', '270k', '48k', '329k', '523k', '921k', '874k',
#        '981k', '784k', '280k', '24k', '518k', '754k', '892k', '154k',
#        '860k', '364k', '387k', '626k', '161k', '879k', '39k', '970k',
#        '170k', '141k', '160k', '144k', '143k', '190k', '376k', '193k',
#        '246k', '73k', '658k', '992k', '253k', '420k', '404k', '1,000+',
#        '470k', '226k', '240k', '89k', '234k', '257k', '861k', '467k',
#        '157k', '44k', '676k', '67k', '552k', '885k', '1020k', '582k',
#        '619k'], dtype=object)

# %%
# convert object to numeric
item = "19m"

# %%
item[-1]
# Out:
# 'm'

# %%
# 1  MB to 1024 kb

def size_process(item):
    if str(item)[-1] == "m":
        res = float(str(item).replace("m", ""))
        res = res * 1024
        return res
    elif str(item)[-1] =="k":
        res = float(str(item).replace("k", ""))
        return res
    else:
        return str(np.NaN)

# %%
size_process("19m")
size_process("20m")
print(size_process("19m"))
print(size_process("20m"))
# Out:
# 19456.0
# 20480.0

# %%
df_copy["Size"] = df_copy["Size"].apply(size_process)
df_copy["Size"].unique()
# Out:
# array(['nan', 201.0, 23.0, 79.0, 118.0, 695.0, 18.0, 556.0, 526.0, 334.0,
#        232.0, 624.0, 8.5, 41.0, 292.0, 11.0, 704.0, 862.0, 899.0, 378.0,
#        266.0, 375.0, 975.0, 980.0, 696.0, 544.0, 525.0, 920.0, 779.0,
#        853.0, 720.0, 713.0, 772.0, 318.0, 58.0, 241.0, 196.0, 857.0, 51.0,
#        953.0, 865.0, 251.0, 930.0, 540.0, 313.0, 746.0, 203.0, 26.0,
#        314.0, 239.0, 371.0, 220.0, 730.0, 756.0, 91.0, 293.0, 17.0, 74.0,
#        14.0, 317.0, 78.0, 924.0, 902.0, 818.0, 81.0, 939.0, 169.0, 45.0,
#        475.0, 965.0, 545.0, 61.0, 283.0, 655.0, 714.0, 93.0, 872.0, 121.0,
#        322.0, 976.0, 172.0, 238.0, 549.0, 206.0, 954.0, 444.0, 717.0,
#        210.0, 609.0, 308.0, 705.0, 306.0, 904.0, 473.0, 175.0, 350.0,
#        383.0, 454.0, 421.0, 70.0, 812.0, 442.0, 842.0, 417.0, 412.0,
#        459.0, 478.0, 335.0, 782.0, 721.0, 430.0, 429.0, 192.0, 200.0,
#        460.0, 728.0, 496.0, 816.0, 414.0, 506.0, 887.0, 613.0, 243.0,
#        569.0, 778.0, 683.0, 592.0, 319.0, 186.0, 840.0, 647.0, 191.0,
#        373.0, 437.0, 598.0, 716.0, 585.0, 982.0, 222.0, 219.0, 55.0,
#        948.0, 323.0, 691.0, 511.0, 951.0, 963.0, 25.0, 554.0, 351.0, 27.0,
#        82.0, 208.0, 913.0, 514.0, 551.0, 29.0, 103.0, 898.0, 743.0, 116.0,
#        153.0, 209.0, 353.0, 499.0, 173.0, 597.0, 809.0, 122.0, 411.0,
#        400.0, 801.0, 787.0, 237.0, 50.0, 643.0, 986.0, 97.0, 516.0, 837.0,
#        780.0, 961.0, 269.0, 20.0, 498.0, 600.0, 749.0, 642.0, 881.0, 72.0,
#        656.0, 601.0, 221.0, 228.0, 108.0, 940.0, 176.0, 33.0, 663.0, 34.0,
#        942.0, 259.0, 164.0, 458.0, 245.0, 629.0, 28.0, 288.0, 775.0,
#        785.0, 636.0, 916.0, 994.0, 309.0, 485.0, 914.0, 903.0, 608.0,
#        500.0, 54.0, 562.0, 847.0, 957.0, 688.0, 811.0, 270.0, 48.0, 329.0,
#        523.0, 921.0, 874.0, 981.0, 784.0, 280.0, 24.0, 518.0, 754.0,
#        892.0, 154.0, 860.0, 364.0, 387.0, 626.0, 161.0, 879.0, 39.0,
#        970.0, 170.0, 141.0, 160.0, 144.0, 143.0, 190.0, 376.0, 193.0,
#        246.0, 73.0, 658.0, 992.0, 253.0, 420.0, 404.0, 470.0, 226.0,
#        240.0, 89.0, 234.0, 257.0, 861.0, 467.0, 157.0, 44.0, 676.0, 67.0,
#        552.0, 885.0, 1020.0, 582.0, 619.0], dtype=object)

# %%
df_copy["Size"].dtypes
# Out:
# dtype('O')

# %%
df_copy.Size = df_copy.Size.astype("float")

# %%
df_copy["Size"].dtypes
# Out:
# dtype('float64')

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10358 entries, 0 to 10357
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          8893 non-null   float64
#  3   Reviews         10358 non-null  object
#  4   Size            315 non-null    float64
#  5   Installs        10358 non-null  object
#  6   Type            10357 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10350 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.0+ MB

# %%
# # 1024kb to 1mb
# def size_process_m(item):
#     if int(str(item)[-1] == "k"):
#         res = int(str(item).replace("k", ""))
#         res = res / 1024
#         return res
#     elif str(item)[-2] == "m":
#         res = int(str(item).replace("m", ""))
#         return res
#     else:
#         return str(np.NaN)

# %%
# print(size_process_m("1024k"))
# print(size_process_m("2048k"))

# %%
# df_copy["Size"] = df_copy["Size"].apply(size_process)
# df_copy["Size"].unique()
# df_copy.info()

# %%
 df_copy["Installs"]
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10353         5,000+
# 10354           100+
# 10355         1,000+
# 10356         1,000+
# 10357    10,000,000+
# Name: Installs, Length: 10358, dtype: object

# %%
df_copy["Installs"] = df_copy["Installs"].str.replace("+", "", regex=False).str.replace(",", "", regex=False)

# %%
#df_copy["Installs"] = pd.to_numeric(df_copy["Installs"], errors="coerce")

# %%
#df_copy["Installs"] = df_copy["Installs"].fillna(0).astype(int)

# %%
#df_copy["Installs"].astype(int)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10358 entries, 0 to 10357
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          8893 non-null   float64
#  3   Reviews         10358 non-null  object
#  4   Size            315 non-null    float64
#  5   Installs        10358 non-null  object
#  6   Type            10357 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10350 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.0+ MB

# %%
df_copy.Price.unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', 'Everyone', '$1.20', '$1.04'], dtype=object)

# %%
char_to_remove = ["=", ",", "$"]
cols_to_remove  = ["Installs", "Price"]

for char in char_to_remove:
    for col in cols_to_remove:
        df_copy[col] = df_copy[col].str.replace(char, "")

# %%
df_copy.Price.unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        'Everyone', '1.20', '1.04'], dtype=object)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10358 entries, 0 to 10357
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          8893 non-null   float64
#  3   Reviews         10358 non-null  object
#  4   Size            315 non-null    float64
#  5   Installs        10358 non-null  object
#  6   Type            10357 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10350 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.0+ MB

# %%
df_copy["Price"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10353    0
# 10354    0
# 10355    0
# 10356    0
# 10357    0
# Name: Price, Length: 10358, dtype: object

# %%
#df_copy["Installs"].astype(int)
df_copy["Price"].astype(float)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10358 entries, 0 to 10357
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          8893 non-null   float64
#  3   Reviews         10358 non-null  object
#  4   Size            315 non-null    float64
#  5   Installs        10358 non-null  object
#  6   Type            10357 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10350 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.0+ MB

# %%
df_copy["Last Updated"]

# %%
df_copy["Last Updated"] = pd.to_datetime(df_copy["Last Updated"], errors="coerce")

# %%
df_copy["Last Updated"]
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10353   2017-07-25
# 10354   2018-07-06
# 10355   2017-01-20
# 10356   2015-01-19
# 10357   2018-07-25
# Name: Last Updated, Length: 10358, dtype: datetime64[ns]

# %%
df_copy["Day "] = df_copy["Last Updated"].dt.day
df_copy["Month"] = df_copy["Last Updated"].dt.month
df_copy["Year"] = df_copy["Last Updated"].dt.year

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews  Size  Installs  Type Price Content Rating  \
# 0         4.1     159   NaN     10000  Free     0       Everyone
# 1         3.9     967   NaN    500000  Free     0       Everyone
# 2         4.7   87510   NaN   5000000  Free     0       Everyone
# 3         4.5  215644   NaN  50000000  Free     0           Teen
# 4         4.3     967   NaN    100000  Free     0       Everyone
# ...       ...     ...   ...       ...   ...   ...            ...
# 10353     4.5      38   NaN      5000  Free     0       Everyone
# 10354     5.0       4   NaN       100  Free     0       Everyone
# 10355     NaN       3   NaN      1000  Free     0       Everyone
# 10356     4.5     114   NaN      1000  Free     0     Mature 17+
# 10357     4.5  398307   NaN  10000000  Free     0       Everyone
#
#                           Genres Last Updated         Current Ver  \
# 0                   Art & Design   2018-01-07               1.0.0
# 1      Art & Design;Pretend Play   2018-01-15               2.0.0
# 2                   Art & Design   2018-08-01               1.2.4
# 3                   Art & Design   2018-06-08  Varies with device
# 4        Art & Design;Creativity   2018-06-20                 1.1
# ...                          ...          ...                 ...
# 10353                  Education   2017-07-25                1.48
# 10354                  Education   2018-07-06                 1.0
# 10355                    Medical   2017-01-20                 1.0
# 10356          Books & Reference   2015-01-19  Varies with device
# 10357                  Lifestyle   2018-07-25  Varies with device
#
#               Android Ver  Day   Month    Year
# 0            4.0.3 and up   7.0    1.0  2018.0
# 1            4.0.3 and up  15.0    1.0  2018.0
# 2            4.0.3 and up   1.0    8.0  2018.0
# 3              4.2 and up   8.0    6.0  2018.0
# 4              4.4 and up  20.0    6.0  2018.0
# ...                   ...   ...    ...     ...
# 10353          4.1 and up  25.0    7.0  2017.0
# 10354          4.1 and up   6.0    7.0  2018.0
# 10355          2.2 and up  20.0    1.0  2017.0
# 10356  Varies with device  19.0    1.0  2015.0
# 10357  Varies with device  25.0    7.0  2018.0
#
# [10358 rows x 16 columns]

# %%
df_copy.dtypes
# Out:
# App                       object
# Category                  object
# Rating                   float64
# Reviews                   object
# Size                     float64
# Installs                  object
# Type                      object
# Price                     object
# Content Rating            object
# Genres                    object
# Last Updated      datetime64[ns]
# Current Ver               object
# Android Ver               object
# Day                      float64
# Month                    float64
# Year                     float64
# dtype: object

# %%
df_copy.drop("Last Updated", axis = 1, inplace = True)

# %%
df_copy

# %%
df_copy["Android Ver"].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '5.1 and up', '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up',
#        '3.2 and up', '4.4W and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
df_copy["Android Ver"] = df_copy["Android Ver"].str.replace("and up", "").str.replace("Varies with device", "")

# %%
df_copy["Android Ver"].unique()
# Out:
# array(['4.0.3 ', '4.2 ', '4.4 ', '2.3 ', '3.0 ', '4.1 ', '4.0 ', '2.3.3 ',
#        '', '2.2 ', '5.0 ', '6.0 ', '1.6 ', '1.5 ', '2.1 ', '7.0 ', '5.1 ',
#        '4.3 ', '4.0.3 - 7.1.1', '2.0 ', '3.2 ', '4.4W ', '7.1 ',
#        '7.0 - 7.1.1', '8.0 ', '5.0 - 8.0', '3.1 ', '2.0.1 ',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 ', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
# internal Assignment >> prepare Android ver
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Day ', 'Month', 'Year'],
#       dtype='object')

# %%
df_copy.App
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10353                                     Sya9a Maroc - FR
# 10354                     Fr. Mike Schmitz Audio Teachings
# 10355                               Parkinson Exercices FR
# 10356                        The SCP Foundation DB fr nn5n
# 10357        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10358, dtype: object

# %%
df_copy[df_copy.duplicated("App")]
# Out:
#                                             App       Category  Rating  \
# 260                Quick PDF Scanner + OCR FREE       BUSINESS     4.2
# 261      OfficeSuite : Free Office + PDF Editor       BUSINESS     4.3
# 262                                       Slack       BUSINESS     4.4
# 348    Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 349               imo free video calls and chat  COMMUNICATION     4.3
# ...                                         ...            ...     ...
# 10165                         Motorola FM Radio  VIDEO_PLAYERS     3.9
# 10233                        FarmersOnly Dating         DATING     3.0
# 10238        Firefox Focus: The privacy browser  COMMUNICATION     4.4
# 10248                               FP Notebook        MEDICAL     4.5
# 10271            Slickdeals: Coupons & Shopping       SHOPPING     4.5
#
#         Reviews  Size    Installs  Type Price Content Rating  \
# 260       80804   NaN     5000000  Free     0       Everyone
# 261     1002859   NaN   100000000  Free     0       Everyone
# 262       51510   NaN     5000000  Free     0       Everyone
# 348    56646578   NaN  1000000000  Free     0       Everyone
# 349     4785988   NaN   500000000  Free     0       Everyone
# ...         ...   ...         ...   ...   ...            ...
# 10165     54815   NaN   100000000  Free     0       Everyone
# 10233      1145   NaN      100000  Free     0     Mature 17+
# 10238     36981   NaN     1000000  Free     0       Everyone
# 10248       410   NaN       50000  Free     0       Everyone
# 10271     33599   NaN     1000000  Free     0       Everyone
#
#                         Genres Last Updated         Current Ver Android Ver  \
# 260                   Business   2018-02-26  Varies with device      4.0.3
# 261                   Business   2018-08-02           9.7.14188        4.1
# 262                   Business   2018-08-02  Varies with device
# 348              Communication   2018-08-01  Varies with device
# 349              Communication   2018-06-08    9.8.000000010501        4.0
# ...                        ...          ...                 ...         ...
# 10165  Video Players & Editors   2018-05-02  Varies with device
# 10233                   Dating   2016-02-25                 2.2        4.0
# 10238            Communication   2018-07-06                 5.2        5.0
# 10248                  Medical   2018-03-24           2.1.0.372        4.4
# 10271                 Shopping   2018-07-30                 3.9        4.4
#
#        Day   Month    Year
# 260    26.0    2.0  2018.0
# 261     2.0    8.0  2018.0
# 262     2.0    8.0  2018.0
# 348     1.0    8.0  2018.0
# 349     8.0    6.0  2018.0
# ...     ...    ...     ...
# 10165   2.0    5.0  2018.0
# 10233  25.0    2.0  2016.0
# 10238   6.0    7.0  2018.0
# 10248  24.0    3.0  2018.0
# 10271  30.0    7.0  2018.0
#
# [698 rows x 16 columns]

# %%
df_copy = df_copy.drop_duplicates(subset = ["App"], keep = 'first')

# %%
df_copy[df_copy.duplicated("App")]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver, Day , Month, Year]
# Index: []

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Day ', 'Month', 'Year'],
#       dtype='object')

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews  Size  Installs  Type Price Content Rating  \
# 0         4.1     159   NaN     10000  Free     0       Everyone
# 1         3.9     967   NaN    500000  Free     0       Everyone
# 2         4.7   87510   NaN   5000000  Free     0       Everyone
# 3         4.5  215644   NaN  50000000  Free     0           Teen
# 4         4.3     967   NaN    100000  Free     0       Everyone
# ...       ...     ...   ...       ...   ...   ...            ...
# 10353     4.5      38   NaN      5000  Free     0       Everyone
# 10354     5.0       4   NaN       100  Free     0       Everyone
# 10355     NaN       3   NaN      1000  Free     0       Everyone
# 10356     4.5     114   NaN      1000  Free     0     Mature 17+
# 10357     4.5  398307   NaN  10000000  Free     0       Everyone
#
#                           Genres Last Updated         Current Ver Android Ver  \
# 0                   Art & Design   2018-01-07               1.0.0      4.0.3
# 1      Art & Design;Pretend Play   2018-01-15               2.0.0      4.0.3
# 2                   Art & Design   2018-08-01               1.2.4      4.0.3
# 3                   Art & Design   2018-06-08  Varies with device        4.2
# 4        Art & Design;Creativity   2018-06-20                 1.1        4.4
# ...                          ...          ...                 ...         ...
# 10353                  Education   2017-07-25                1.48        4.1
# 10354                  Education   2018-07-06                 1.0        4.1
# 10355                    Medical   2017-01-20                 1.0        2.2
# 10356          Books & Reference   2015-01-19  Varies with device
# 10357                  Lifestyle   2018-07-25  Varies with device
#
#        Day   Month    Year
# 0       7.0    1.0  2018.0
# 1      15.0    1.0  2018.0
# 2       1.0    8.0  2018.0
# 3       8.0    6.0  2018.0
# 4      20.0    6.0  2018.0
# ...     ...    ...     ...
# 10353  25.0    7.0  2017.0
# 10354   6.0    7.0  2018.0
# 10355  20.0    1.0  2017.0
# 10356  19.0    1.0  2015.0
# 10357  25.0    7.0  2018.0
#
# [9660 rows x 16 columns]

# %%
# Exploratory data analysis 
categorical_feature = [feature for feature in df_copy.columns if df_copy[feature].dtype == 'O']

# %%
categorical_feature
# Out:
# ['App',
#  'Category',
#  'Reviews',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Current Ver',
#  'Android Ver']

# %%
numerical_feature = [feature for feature in df_copy.columns if df_copy[feature].dtype != 'O']

# %%
numerical_feature
# Out:
# ['Rating', 'Size', 'Last Updated', 'Day ', 'Month', 'Year']

# %%
# Categorical data >> freq plot, bar chart, pie chart,
# Numerical data >> histogram, displot, box plot, line chart, pairplot, scatter plot

# %%
# Categorical feature analysis 
df_copy["Type"].value_counts(normalize = True)
# Out:
# Type
# Free    0.921627
# Paid    0.078269
# 0       0.000104
# Name: proportion, dtype: float64

# %%
for col in categorical_feature:
     print(f"{col} : {df_copy[col].value_counts(normalize=True)*100}")
# Out:
# App : App
# Photo Editor & Candy Camera & Grid & ScrapBook    0.010352
# CK Pharmacies                                     0.010352
# CK Call NEW                                       0.010352
# Ck Coif                                           0.010352
# CONTRACT KILLER: ZOMBIES                          0.010352
#                                                     ...
# Bike Race Free - Top Motorcycle Racing Games      0.010352
# Dance School Stories - Dance Dreams Come True     0.010352
# 3D Bowling                                        0.010352
# Mind Games Pro                                    0.010352
# iHoroscope - 2018 Daily Horoscope & Astrology     0.010352
# Name: proportion, Length: 9660, dtype: float64
# Category : Category
# FAMILY                 18.964803
# GAME                    9.927536
# TOOLS                   8.561077
# BUSINESS                4.347826
# MEDICAL                 4.089027
# PERSONALIZATION         3.892340
# PRODUCTIVITY            3.871636
# LIFESTYLE               3.819876
# FINANCE                 3.571429
# SPORTS                  3.364389
# COMMUNICATION           3.260870
# HEALTH_AND_FITNESS      2.981366
# PHOTOGRAPHY             2.908903
# NEWS_AND_MAGAZINES      2.629400
# SOCIAL                  2.474120
# BOOKS_AND_REFERENCE     2.298137
# TRAVEL_AND_LOCAL        2.267081
# SHOPPING                2.091097
# DATING                  1.770186
# VIDEO_PLAYERS           1.687371
# MAPS_AND_NAVIGATION     1.356108
# EDUCATION               1.231884
# FOOD_AND_DRINK          1.159420
# ENTERTAINMENT           1.055901
# AUTO_AND_VEHICLES       0.879917
# LIBRARIES_AND_DEMO      0.869565
# WEATHER                 0.817805
# HOUSE_AND_HOME          0.766046
# ART_AND_DESIGN          0.662526
# EVENTS                  0.662526
# PARENTING               0.621118
# COMICS                  0.579710
# BEAUTY                  0.548654
# 1.9                     0.010352
# Name: proportion, dtype: float64
# Reviews : Reviews
# 0         6.138716
# 1         2.815735
# 2         2.204969
# 3         1.759834
# 4         1.418219
#             ...
# 157506    0.010352
# 351254    0.010352
# 49211     0.010352
# 88860     0.010352
# 398307    0.010352
# Name: proportion, Length: 5331, dtype: float64
# Installs : Installs
# 1000000       14.668737
# 100000        11.511387
# 10000         10.672878
# 10000000       9.699793
# 1000           9.192547
# 100            7.349896
# 5000000        6.283644
# 500000         5.227743
# 50000          4.855072
# 5000           4.844720
# 10             3.985507
# 500            3.395445
# 50             2.111801
# 50000000       2.091097
# 100000000      1.946170
# 5              0.848861
# 1              0.693582
# 500000000      0.248447
# 1000000000     0.207039
# 0              0.155280
# Free           0.010352
# Name: proportion, dtype: float64
# Type : Type
# Free    92.162750
# Paid     7.826897
# 0        0.010353
# Name: proportion, dtype: float64
# Price : Price
# 0         92.163561
# 0.99       1.501035
# 2.99       1.283644
# 1.99       0.755694
# 4.99       0.724638
#             ...
# 389.99     0.010352
# 19.90      0.010352
# 1.75       0.010352
# 14.00      0.010352
# 1.04       0.010352
# Name: proportion, Length: 93, dtype: float64
# Content Rating : Content Rating
# Everyone           81.820064
# Teen               10.725748
# Mature 17+          4.068744
# Everyone 10+        3.333678
# Adults only 18+     0.031059
# Unrated             0.020706
# Name: proportion, dtype: float64
# Genres : Genres
# Tools                              8.550725
# Entertainment                      5.807453
# Education                          5.279503
# Business                           4.347826
# Medical                            4.089027
#                                      ...
# Art & Design;Pretend Play          0.010352
# Lifestyle;Pretend Play             0.010352
# Comics;Creativity                  0.010352
# Art & Design;Action & Adventure    0.010352
# Strategy;Creativity                0.010352
# Name: proportion, Length: 119, dtype: float64
# Current Ver : Current Ver
# Varies with device    10.930377
# 1.0                    8.278077
# 1.1                    2.693742
# 1.2                    1.823456
# 2.0                    1.543722
#                         ...
# 2.27.1                 0.010361
# 1.6.11                 0.010361
# 20180517               0.010361
# 3.1.00                 0.010361
# 2.0.148.0              0.010361
# Name: proportion, Length: 2818, dtype: float64
# Android Ver : Android Ver
# 4.1              22.802112
# 4.0.3            14.445480
# 4.0              13.306410
#                  10.251631
# 4.4               8.470540
# 2.3               6.378793
# 5.0               5.301854
# 4.2               3.852128
# 2.3.3             2.826965
# 2.2               2.474889
# 3.0               2.392047
# 4.3               2.288495
# 2.1               1.377239
# 1.6               1.201201
# 6.0               0.559180
# 7.0               0.434918
# 3.2               0.372787
# 2.0               0.331366
# 5.1               0.227814
# 1.5               0.207104
# 4.4W              0.113907
# 3.1               0.103552
# 2.0.1             0.072486
# 8.0               0.062131
# 7.1               0.031066
# 4.0.3 - 7.1.1     0.020710
# 5.0 - 8.0         0.020710
# 1.0               0.020710
# 7.0 - 7.1.1       0.010355
# 4.1 - 7.1.1       0.010355
# 5.0 - 6.0         0.010355
# 2.2 - 7.1.1       0.010355
# 5.0 - 7.1.1       0.010355
# Name: proportion, dtype: float64

# %%
df_copy["Android Ver"].value_counts(normalize = True)*100
# Out:
# Android Ver
# 4.1              22.802112
# 4.0.3            14.445480
# 4.0              13.306410
#                  10.251631
# 4.4               8.470540
# 2.3               6.378793
# 5.0               5.301854
# 4.2               3.852128
# 2.3.3             2.826965
# 2.2               2.474889
# 3.0               2.392047
# 4.3               2.288495
# 2.1               1.377239
# 1.6               1.201201
# 6.0               0.559180
# 7.0               0.434918
# 3.2               0.372787
# 2.0               0.331366
# 5.1               0.227814
# 1.5               0.207104
# 4.4W              0.113907
# 3.1               0.103552
# 2.0.1             0.072486
# 8.0               0.062131
# 7.1               0.031066
# 4.0.3 - 7.1.1     0.020710
# 5.0 - 8.0         0.020710
# 1.0               0.020710
# 7.0 - 7.1.1       0.010355
# 4.1 - 7.1.1       0.010355
# 5.0 - 6.0         0.010355
# 2.2 - 7.1.1       0.010355
# 5.0 - 7.1.1       0.010355
# Name: proportion, dtype: float64

# %%
df_copy["Type"].value_counts(normalize=True)*100
# Out:
# Type
# Free    92.162750
# Paid     7.826897
# 0        0.010353
# Name: proportion, dtype: float64

# %%
sns.countplot(x = df_copy["Type"])
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
    sns.countplot(x = df_copy["Content Rating"])
# Out:
# <Axes: xlabel='Content Rating', ylabel='count'>

# %%
# numerical Feature

# %%
numerical_feature
# Out:
# ['Rating', 'Size', 'Last Updated', 'Day ', 'Month', 'Year']

# %%
sns.displot(df_copy["Price"], kde = True)

# %%
sns.distplot(df_copy["Rating"], kde = True)
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
sns.kdeplot(df_copy["Rating"])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
plt.figure(figsize = (20, 8))
category = ["Type", "Content Rating"]
for i in range(0, len(category)):
    plt.subplot(1, 2, i+1)
    sns.countplot(x = df[category[i]], palette = "Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation = 45)
    plt.tight_layout()

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews  Size  Installs  Type Price Content Rating  \
# 0         4.1     159   NaN     10000  Free     0       Everyone
# 1         3.9     967   NaN    500000  Free     0       Everyone
# 2         4.7   87510   NaN   5000000  Free     0       Everyone
# 3         4.5  215644   NaN  50000000  Free     0           Teen
# 4         4.3     967   NaN    100000  Free     0       Everyone
# ...       ...     ...   ...       ...   ...   ...            ...
# 10353     4.5      38   NaN      5000  Free     0       Everyone
# 10354     5.0       4   NaN       100  Free     0       Everyone
# 10355     NaN       3   NaN      1000  Free     0       Everyone
# 10356     4.5     114   NaN      1000  Free     0     Mature 17+
# 10357     4.5  398307   NaN  10000000  Free     0       Everyone
#
#                           Genres Last Updated         Current Ver Android Ver  \
# 0                   Art & Design   2018-01-07               1.0.0      4.0.3
# 1      Art & Design;Pretend Play   2018-01-15               2.0.0      4.0.3
# 2                   Art & Design   2018-08-01               1.2.4      4.0.3
# 3                   Art & Design   2018-06-08  Varies with device        4.2
# 4        Art & Design;Creativity   2018-06-20                 1.1        4.4
# ...                          ...          ...                 ...         ...
# 10353                  Education   2017-07-25                1.48        4.1
# 10354                  Education   2018-07-06                 1.0        4.1
# 10355                    Medical   2017-01-20                 1.0        2.2
# 10356          Books & Reference   2015-01-19  Varies with device
# 10357                  Lifestyle   2018-07-25  Varies with device
#
#        Day   Month    Year
# 0       7.0    1.0  2018.0
# 1      15.0    1.0  2018.0
# 2       1.0    8.0  2018.0
# 3       8.0    6.0  2018.0
# 4      20.0    6.0  2018.0
# ...     ...    ...     ...
# 10353  25.0    7.0  2017.0
# 10354   6.0    7.0  2018.0
# 10355  20.0    1.0  2017.0
# 10356  19.0    1.0  2015.0
# 10357  25.0    7.0  2018.0
#
# [9660 rows x 16 columns]

# %%
#Q. which category is the most popular category in the app
df_copy["Category"].value_counts().plot.pie(y = df["Category"], figsize = (12, 12), autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# Insights >> The most popular category as Family with 19% of the share

# %%
# what is top 10 most popular category
cat = df_copy["Category"].value_counts()[:10]

# %%
category = cat.reset_index()

# %%
category.columns = ["Groups", "count"]

# %%
sns.barplot(category, x = category["Groups"], y = category["count"])
# Out:
# <Axes: xlabel='Groups', ylabel='count'>

# %%
# Which category has the highest instaliation
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Day ', 'Month', 'Year'],
#       dtype='object')

# %%
df_copy.groupby(["Category"])["Installs"].sum().sort_values(ascending = False).reset_index()
# Out:
#                Category                                           Installs
# 0                   1.9                                               Free
# 1    LIBRARIES_AND_DEMO  5000010000100000100010000010000100000500000050...
# 2                BEAUTY  5000001000000100000500000100000050000010000010...
# 3             LIFESTYLE  5000000100000001000001000000050000001000000500...
# 4               WEATHER  5000000010000005000000010000100000001000000100...
# 5       PERSONALIZATION  5000000010000001000000005000000100000500000050...
# 6          PRODUCTIVITY  5000000001000000010000000010000000100000000010...
# 7        ART_AND_DESIGN  1000050000050000005000000010000050000500001000...
# 8             PARENTING  1000050000001000010000001000010000100000100005...
# 9                DATING  1000010005010010010010000000100000001000000010...
# 10               EVENTS  1000005000000500000500005000000100000010000100...
# 11              MEDICAL  1000001000010000100001000010000500050001000005...
# 12    AUTO_AND_VEHICLES  1000001000000100000100000010000010000010000050...
# 13               FAMILY  1000000500000050000001000000100000050000001000...
# 14          PHOTOGRAPHY  1000000500000010000005000005000010000001000000...
# 15       FOOD_AND_DRINK  1000000050000100000001000000100001000001000000...
# 16   HEALTH_AND_FITNESS  1000000050000050000001000000100000001000000010...
# 17               COMICS  1000000050000010000005000005000050000500001000...
# 18     TRAVEL_AND_LOCAL  1000000050000000500000010000005000001000000100...
# 19             BUSINESS  1000000050000000100000005000000100000050000000...
# 20       HOUSE_AND_HOME  1000000010000010000001000000050000001000000100...
# 21               SPORTS  1000000010000010000000500000050000000100000001...
# 22              FINANCE  1000000010000005000000500000050000001000000050...
# 23   NEWS_AND_MAGAZINES  1000000010000000100000010000001000000010000001...
# 24             SHOPPING  1000000010000000010000000100000001000000050000...
# 25                TOOLS  1000000010000000005000000001000000050000000500...
# 26  BOOKS_AND_REFERENCE  1000000005000010000010000000100000000100000001...
# 27  MAPS_AND_NAVIGATION  1000000005000000100000001000000050000005000000...
# 28        ENTERTAINMENT  1000000001000000100000010000000500000001000000...
# 29            EDUCATION  1000000001000000010000050000001000000010000050...
# 30                 GAME  1000000001000000000500000000100000001000000050...
# 31        VIDEO_PLAYERS  1000000000100000010000000100000010000001000000...
# 32               SOCIAL  1000000000100000000050000000010000000100000000...
# 33        COMMUNICATION  1000000000100000000010000000100000000010000000...

# %%
sns.boxplot(df_copy["Rating"])
# Out:
# <Axes: ylabel='Rating'>

# %%
sns.boxplot(x= "Installs", y = "Rating", data=df_copy)
# Out:
# <Axes: xlabel='Installs', ylabel='Rating'>
