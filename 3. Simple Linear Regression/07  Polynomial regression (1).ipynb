# %% [markdown]
# ##  Polynomial regression:
# ### -Polynomial regression is just linear regression with extra powers of the input variable(s).
#
# ### Example: Instead of fitting a straight line
#   - y=b0​+b1​x

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Genrate same synthetics dp or repraduciblitiy of results
np.random.seed(1)

# %%
# Genrate synthtic X
x = 2*np.random.rand(100, 1)

# %%
x
# Out:
# array([[8.34044009e-01],
#        [1.44064899e+00],
#        [2.28749635e-04],
#        [6.04665145e-01],
#        [2.93511782e-01],
#        [1.84677190e-01],
#        [3.72520423e-01],
#        [6.91121454e-01],
#        [7.93534948e-01],
#        [1.07763347e+00],
#        [8.38389029e-01],
#        [1.37043900e+00],
#        [4.08904499e-01],
#        [1.75623487e+00],
#        [5.47751864e-02],
#        [1.34093502e+00],
#        [8.34609605e-01],
#        [1.11737966e+00],
#        [2.80773877e-01],
#        [3.96202978e-01],
#        [1.60148914e+00],
#        [1.93652315e+00],
#        [6.26848356e-01],
#        [1.38464523e+00],
#        [1.75277830e+00],
#        [1.78921333e+00],
#        [1.70088423e-01],
#        [7.81095665e-02],
#        [3.39660839e-01],
#        [1.75628501e+00],
#        [1.96693668e-01],
#        [8.42215250e-01],
#        [1.91577906e+00],
#        [1.06633057e+00],
#        [1.38375423e+00],
#        [6.31031262e-01],
#        [1.37300186e+00],
# ...

# %%
# Generate random sythetic y usiong x
y = 4 + 3*x+1.5*x**2 + np.random.rand(100, 1)

# %%
y
# Out:
# array([[ 7.87222104],
#        [11.96220932],
#        [ 4.88662843],
#        [ 6.7196951 ],
#        [ 5.91829424],
#        [ 5.22855018],
#        [ 5.34153971],
#        [ 7.71927489],
#        [ 8.01604833],
#        [ 9.97216409],
#        [ 7.74185184],
#        [11.06560733],
#        [ 6.4101133 ],
#        [14.59206417],
#        [ 4.23482621],
#        [11.47542821],
#        [ 8.30256479],
#        [10.14796945],
#        [ 5.67209735],
#        [ 5.5483451 ],
#        [12.67149873],
#        [15.46096332],
#        [ 6.49825985],
#        [11.27601039],
#        [14.72671054],
#        [14.70839754],
#        [ 5.10648235],
#        [ 5.08551125],
#        [ 5.31621006],
#        [14.17484424],
#        [ 5.23387287],
#        [ 8.56023129],
#        [15.81368151],
#        [ 8.92323033],
#        [11.824059  ],
#        [ 6.72336874],
#        [11.7538119 ],
#        [13.57521475],
#        [ 4.97527829],
#        [12.62428649],
#        [16.35648429],
# ...

# %%
# train test split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,  y, test_size=0.25, random_state=1)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((75, 1), (25, 1), (75, 1), (25, 1))

# %%
# perfrom polynomial regression
from sklearn.preprocessing import PolynomialFeatures
poly_features =  PolynomialFeatures(degree=2, include_bias=False)

# %%
poly_features
# Out:
# PolynomialFeatures(include_bias=False)

# %%
x_poly_train = poly_features.fit_transform(x_train)

# %%
x_poly_train
# Out:
# array([[6.31031262e-01, 3.98200454e-01],
#        [8.16273606e-01, 6.66302599e-01],
#        [7.81095665e-02, 6.10110437e-03],
#        [1.81719101e+00, 3.30218315e+00],
#        [3.65765547e-02, 1.33784435e-03],
#        [1.02977822e+00, 1.06044319e+00],
#        [1.23428983e+00, 1.52347138e+00],
#        [9.83146319e-01, 9.66576684e-01],
#        [4.74053960e-01, 2.24727157e-01],
#        [1.32688300e+00, 1.76061848e+00],
#        [1.97772218e+00, 3.91138501e+00],
#        [5.75550677e-01, 3.31258582e-01],
#        [1.39951672e+00, 1.95864705e+00],
#        [1.38464523e+00, 1.91724242e+00],
#        [1.38375423e+00, 1.91477576e+00],
#        [8.56182380e-01, 7.33048267e-01],
#        [5.31093319e-01, 2.82060113e-01],
#        [6.95531719e-01, 4.83764373e-01],
#        [1.34093502e+00, 1.79810673e+00],
#        [6.97796684e-01, 4.86920212e-01],
#        [1.49633131e+00, 2.23900739e+00],
#        [8.95787052e-01, 8.02434443e-01],
#        [1.89897852e+00, 3.60611941e+00],
# ...

# %%
from sklearn.linear_model import LinearRegression
poly_reg = LinearRegression()

# %%
poly_reg
# Out:
# LinearRegression()

# %%
poly_reg.fit(x_poly_train, y_train)
# Out:
# LinearRegression()

# %%
poly_reg.coef_
# Out:
# array([[3.13310673, 1.41399002]])

# %%
poly_reg.intercept_
# Out:
# array([4.4668922])

# %%
# make prediction on train data itself for the evaluation metrics
y_poly_pred = poly_reg.predict(x_poly_train)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_train, y_poly_pred)
# Out:
# 0.09767603323256355

# %%
    plt.scatter(x_train, y_train, label="train data")

# %%
# raiddy
